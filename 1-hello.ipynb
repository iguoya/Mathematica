# %%
Table[RandomColor[],10]
# Out:
# {RGBColor[0.0985485, 0.778341, 0.931829], RGBColor[0.669914, 0.715295, 0.97774],
#
# >   RGBColor[0.71126, 0.842619, 0.468909], RGBColor[0.0717718, 0.862679, 0.751135],
#
# >   RGBColor[0.909811, 0.822134, 0.0058443], RGBColor[0.411307, 0.682552, 0.795885],
#
# >   RGBColor[0.361964, 0.58651, 0.281301], RGBColor[0.541665, 0.930268, 0.155626],
#
# >   RGBColor[0.25192, 0.816574, 0.390988], RGBColor[0.574104, 0.026685, 0.253482]}

# %%
Integrate[x^5+6x+2,{x,-3,2}]
# Out:
#   695
# -(---)
#    6

# %%
Plot3D[Sin[x*y],{x,-Pi,Pi},{y,-Pi,Pi}]
# Out:
# -Graphics3D-

# %%
Graph[Table[i -> Mod[i^2, 74], {i, 100}]]
# Out:
# Graph[<101>, <100>]
