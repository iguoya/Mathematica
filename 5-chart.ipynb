# %%
E
# Out:
# E

# %%
table={1,2,4,6,7,8,22}
# Out:
# {1, 2, 4, 6, 7, 8, 22}

# %%
Plot[x,{x,-100,100}]
# Out:
# -Graphics-

# %%
Plot[x*2, {x, -100,100}]
# Out:
# -Graphics-

# %%
Plot[x^2, {x, -100,100}]
# Out:
# -Graphics-

# %%
Plot[Sqrt[x], {x, 0,10000}]
# Out:
# -Graphics-

# %%
Plot[x^3, {x, -100, 100}]
# Out:
# -Graphics-

# %%
Plot[1/x, {x, -100, 100}]
# Out:
# -Graphics-

# %%
Plot[x*Sin[1/x], {x, -0.5, 0.5}]
# Out:
# -Graphics-

# %%
Plot[Sin[x], {x, -10*Pi, 10*Pi}]
# Out:
# -Graphics-

# %%
Plot[Cos[x], {x, -10*Pi, 10*Pi}]
# Out:
# -Graphics-

# %%
Plot[Tan[x], {x, -10*Pi, 10*Pi}]
# Out:
# -Graphics-
