# %%
Pi
# Out:
# Pi

# %%
ParametricPlot[{100*Cos[t], 100*Sin[t]}, {t, -Pi,Pi}]
# Out:
# -Graphics-

# %%
R=100
# Out:
# 100

# %%
ParametricPlot[{3Cos[t], Sin[t]}, {t, 0,2Pi}]
# Out:
# -Graphics-

# %%
Plot3D[Sin[x] Cos[y], {x, -100, 100}, {y, -100, 100}]
# Out:
# -Graphics3D-

# %%
Plot3D[Sin[x] Cos[y], {x, -Pi, Pi}, {y, -Pi, Pi}]
# Out:
# -Graphics3D-

# %%
Plot3D[Sin[x] Cos[y], {x, 0, Pi}, {y, 0, Pi}]
# Out:
# -Graphics3D-
